# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pip install seaborn
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set_style('dark')
# %pip install pycountry_convert
import pycountry_convert as pc
# Out:
# Requirement already satisfied: seaborn in c:\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\python310\lib\site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\python310\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.23 in c:\python310\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pycountry_convert in c:\python310\lib\site-packages (0.7.2)
# Requirement already satisfied: pytest-mock>=1.6.3 in c:\python310\lib\site-packages (from pycountry_convert) (3.8.2)
# Requirement already satisfied: repoze.lru>=0.7 in c:\python310\lib\site-packages (from pycountry_convert) (0.7)
# Requirement already satisfied: pytest-cov>=2.5.1 in c:\python310\lib\site-packages (from pycountry_convert) (3.0.0)
# Requirement already satisfied: pytest>=3.4.0 in c:\python310\lib\site-packages (from pycountry_convert) (7.1.2)
# Requirement already satisfied: pprintpp>=0.3.0 in c:\python310\lib\site-packages (from pycountry_convert) (0.4.0)
# Requirement already satisfied: wheel>=0.30.0 in c:\python310\lib\site-packages (from pycountry_convert) (0.37.1)
# Requirement already satisfied: pycountry>=16.11.27.1 in c:\python310\lib\site-packages (from pycountry_convert) (22.3.5)
# Requirement already satisfied: setuptools in c:\python310\lib\site-packages (from pycountry>=16.11.27.1->pycountry_convert) (58.1.0)
# Requirement already satisfied: py>=1.8.2 in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.4.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.0.0)
# Requirement already satisfied: packaging in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.1)
# Requirement already satisfied: iniconfig in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (22.1.0)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.4.5)
# Requirement already satisfied: coverage[toml]>=5.2.1 in c:\python310\lib\site-packages (from pytest-cov>=2.5.1->pycountry_convert) (6.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python310\lib\site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# from https://stackoverflow.com/questions/55910004/get-continent-name-from-country-using-pycountry

def country_to_continent(row):
    country_name=row['Country']

    Europe_list=['Euro area','Britain']
    if country_name in Europe_list:
        return 'Europe'
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    
    return country_continent_name

# %%
# %pip install xlrd
big_mac_df=pd.read_excel('data/big-mac-2022-07-01.xls',sheet_name=0)
big_mac_df.head()
# Out:
# Requirement already satisfied: xlrd in c:\python310\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
#        Country iso_a3 currency_code  local_price  dollar_ex  dollar_price  \
# 0  Switzerland    CHE           CHF         6.50    0.96845      6.711756
# 1       Norway    NOR           NOK        62.00    9.89765      6.264113
# 2      Uruguay    URY           UYU       255.00   41.91000      6.084467
# 3       Sweden    SWE           SEK        57.00   10.19785      5.589413
# 4       Canada    CAN           CAD         6.77    1.28915      5.251522
#
#    dollar_ppp    GDP_bigmac  dollar_valuation  euro_valuation  \
# 0    1.262136  67857.662938            30.325          40.853
# 1   12.038835  63567.854704            21.633          31.459
# 2   49.514563  14726.863618            18.145          27.689
# 3   11.067961  46516.137374             8.532          17.300
# 4    1.314563  49674.334129             1.971          10.209
#
#    sterling_valuation  yen_valuation  yuan_valuation  dollar_adj_valuation  \
# 0              51.165        137.261          88.694                31.013
# 1              41.083        121.436          76.109                24.323
# 2              37.037        115.086          71.058                49.213
# 3              25.888         97.586          57.141                18.845
# 4              18.277         85.641          47.641                10.205
#
#    euro_adj_valuation  sterling_adj_valuation  yen_adj_valuation  \
# 0              25.768                  39.572            127.382
# 1              19.346                  32.445            115.772
# 2              43.239                  58.961            158.970
# 3              14.087                  26.609            106.264
# 4               5.793                  17.404             91.268
#
#    yuan_adj_valuation
# 0              51.915
# 1              44.158
# 2              73.019
# 3              37.806
# 4              27.787

# %%
big_mac_df.sort_values(by='dollar_price',ascending=True)
# Out:
#                  Country iso_a3 currency_code  local_price     dollar_ex  \
# 53             Venezuela    VEN           VES        10.00      5.673200
# 52               Romania    ROU           RON        11.00      4.821750
# 51             Indonesia    IDN           IDR     35000.00  14977.500000
# 50          South Africa    ZAF           ZAR        39.90     17.036250
# 49                 India    IND           INR       191.00     79.951300
# 48                 Egypt    EGY           EGP        46.00     18.945000
# 47              Malaysia    MYS           MYR        10.90      4.450000
# 46                Taiwan    TWN           TWD        75.00     29.907500
# 45               Hungary    HUN           HUF      1030.00    389.046150
# 44             Hong Kong    HKG           HKD        21.00      7.849950
# 43                Turkey    TUR           TRY        47.00     17.565000
# 42           Philippines    PHL           PHP       155.00     56.265000
# 41            Azerbaijan    AZE           AZN         4.70      1.698250
# 40                 Japan    JPN           JPY       390.00    137.865000
# 39               Vietnam    VNM           VND     69000.00  23417.000000
# 38               Moldova    MDA           MDL        60.00     19.298000
# 37              Pakistan    PAK           PKR       700.00    221.750000
# 36                Jordan    JOR           JOD         2.30      0.710150
# 35             Guatemala    GTM           GTQ        26.00      7.727900
# 34                Mexico    MEX           MXN        70.00     20.412500
# 33              Colombia    COL           COP     14950.00   4295.100000
# 32              Thailand    THA           THB       128.00     36.612500
# 31           South Korea    KOR           KRW      4600.00   1313.450000
# 30                 China    CHN           CNY        24.00      6.747350
# 29                 Qatar    QAT           QAR        13.00      3.641750
# 28                  Peru    PER           PEN        13.90      3.892850
# 27                Poland    POL           PLN        16.68      4.648450
# 26              Honduras    HND           HNL        89.00     24.615000
# 25                 Chile    CHL           CLP      3400.00    928.435000
# 24               Croatia    HRV           HRK        27.00      7.328450
# 23                  Oman    OMN           OMR         1.42      0.385000
# 22             Sri Lanka    LKA           LKR      1340.00    360.000000
# 21             Nicaragua    NIC           NIO       139.00     35.890000
# 20            Costa Rica    CRI           CRC      2650.00    678.105000
# 19        Czech Republic    CZE           CZK        95.00     23.920000
# 18                Kuwait    KWT           KWD         1.30      0.307400
# 17             Singapore    SGP           SGD         5.90      1.391400
# 16               Bahrain    BHR           BHD         1.60      0.377000
# 15                Brazil    BRA           BRL        22.90      5.391750
# 14           New Zealand    NZL           NZD         7.10      1.603721
# 13               Britain    GBR           GBP         3.69      0.831080
# 12          Saudi Arabia    SAU           SAR        17.00      3.755000
# 11             Argentina    ARG           ARS       590.00    129.115000
# 10             Australia    AUS           AUD         6.70      1.448436
# 9              Euro area    EUZ           EUR         4.65      0.975850
# 8   United Arab Emirates    ARE           AED        18.00      3.673050
# 7                 Israel    ISR           ILS        17.00      3.437450
# 6                Lebanon    LBN           LBP    130000.00  25600.000000
# 5          United States    USA           USD         5.15      1.000000
# 4                 Canada    CAN           CAD         6.77      1.289150
# 3                 Sweden    SWE           SEK        57.00     10.197850
# 2                Uruguay    URY           UYU       255.00     41.910000
# 1                 Norway    NOR           NOK        62.00      9.897650
# 0            Switzerland    CHE           CHF         6.50      0.968450
#
#     dollar_price    dollar_ppp    GDP_bigmac  dollar_valuation  \
# 53      1.762674      1.941748           NaN           -65.773
# 52      2.281329      2.135922  28569.017768           -55.702
# 51      2.336839   6796.116505   9172.246719           -54.624
# 50      2.342065      7.747573  13261.543640           -54.523
# 49      2.388954     37.087379   4579.833524           -53.613
# 48      2.428081      8.932039   6918.453014           -52.853
# 47      2.449438      2.116505  22311.919060           -52.438
# 46      2.507732     14.563107  64992.899747           -51.306
# 45      2.647501    200.000000  28284.494795           -48.592
# 44      2.675176      4.077670  94795.185536           -48.055
# 43      2.675776      9.126214   9256.997784           -48.043
# 42      2.754821     30.097087   5845.332898           -46.508
# 41      2.767555      0.912621  10055.076957           -46.261
# 40      2.828854     75.728155  57016.008440           -45.071
# 39      2.946577  13398.058252   6375.564885           -42.785
# 38      3.109130     11.650485   8024.776007           -39.629
# 37      3.156708    135.922330   1834.014182           -38.705
# 36      3.238752      0.446602   7011.581696           -37.112
# 35      3.364433      5.048544   7161.025481           -34.671
# 34      3.429271     13.592233  14973.726823           -33.412
# 0                 31.013              25.768                  39.572
#
#     yen_adj_valuation  yuan_adj_valuation
# 53                NaN                 NaN
# 52             -8.980             -39.189
# 51              2.200             -31.719
# 50              0.394             -32.926
# 49              6.914             -28.570
# 48              7.391             -28.252
# 47              0.574             -32.806
# 46            -14.097             -42.608
# 45              5.766             -29.337
# 44            -17.866             -45.126
# 43             16.974             -21.849
# 42             22.501             -18.156
# 41             20.510             -19.487
# 40              0.000             -33.189
# 39             30.679             -12.693
# 38             36.754              -8.634
# 37             43.269              -4.281
# 36             43.179              -4.342
# 35             48.623              -0.704
# 34             45.784              -2.601
# 33             53.162               2.329
# 32             52.797               2.085
# 31             30.302             -12.945
# 30             49.677               0.000
# 29              8.057             -27.807
# 28             55.868               4.136
# 27             48.074              -1.071
# 26             62.342               8.462
# 25             53.097               2.285
# 24             52.632               1.974
# 23             49.215              -0.308
# 22             68.049              12.274
# 21             74.871              16.832
# 20             66.136              10.996
# 19             56.708               4.698
# 18             64.414               9.846
# 17             34.604             -10.070
# 16             67.015              11.584
# 15             85.742              24.095
# 14             61.265               7.742
# 13             62.914               8.844
# 12             82.165              21.706
# 11            100.170              33.735
# 10             58.476               5.879
# 9              80.795              20.790
# 8              81.952              21.563
# 7              79.649              20.025
# 6                 NaN                 NaN
# 5              73.557              15.955
# 4              91.268              27.787
# 3             106.264              37.806
# 2             158.970              73.019
# 1             115.772              44.158
# 0             127.382              51.915

# %%
big_mac_df.Country.unique()
# Out:
# array(['Switzerland', 'Norway', 'Uruguay', 'Sweden', 'Canada',
#        'United States', 'Lebanon', 'Israel', 'United Arab Emirates',
#        'Euro area', 'Australia', 'Argentina', 'Saudi Arabia', 'Britain',
#        'New Zealand', 'Brazil', 'Bahrain', 'Singapore', 'Kuwait',
#        'Czech Republic', 'Costa Rica', 'Nicaragua', 'Sri Lanka', 'Oman',
#        'Croatia', 'Chile', 'Honduras', 'Poland', 'Peru', 'Qatar', 'China',
#        'South Korea', 'Thailand', 'Colombia', 'Mexico', 'Guatemala',
#        'Jordan', 'Pakistan', 'Moldova', 'Vietnam', 'Japan', 'Azerbaijan',
#        'Philippines', 'Turkey', 'Hong Kong', 'Hungary', 'Taiwan',
#        'Malaysia', 'Egypt', 'India', 'South Africa', 'Indonesia',
#        'Romania', 'Venezuela'], dtype=object)

# %%
big_mac_df.columns
# Out:
# Index(['Country', 'iso_a3', 'currency_code', 'local_price', 'dollar_ex',
#        'dollar_price', 'dollar_ppp', 'GDP_bigmac', 'dollar_valuation',
#        'euro_valuation', 'sterling_valuation', 'yen_valuation',
#        'yuan_valuation', 'dollar_adj_valuation', 'euro_adj_valuation',
#        'sterling_adj_valuation', 'yen_adj_valuation', 'yuan_adj_valuation'],
#       dtype='object')

# %%
xrate_index_df=big_mac_df[['Country','dollar_ex','dollar_ppp','dollar_price']]

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(np.log(np.array(xrate_index_df['dollar_ppp']).reshape(-1,1)),np.log(xrate_index_df['dollar_ex']))
# Out:
# (array([1.01580367]), 0.31472663788656474)

# %%
coeff=np.round(lr.coef_[0],2)
intercept=np.round(lr.intercept_,2)
corr=np.round(xrate_index_df[['dollar_ppp','dollar_ex']].corr()['dollar_ppp'][1],2)
_,ax=plt.subplots(1,1,figsize=(13,8))
sns.regplot(np.log(xrate_index_df['dollar_ppp']),np.log(xrate_index_df['dollar_ex']),data=xrate_index_df,ax=ax,\
    label=f'{coeff}x+{intercept}\n r = {corr}')
ax.set_xlabel('dollar purchasing power parity (log scale)',fontsize=13)
ax.set_ylabel('USD / local currency (log scale)',fontsize=13)
ax.set_title('The Big Mac Index and Currency Exchange Rate',fontsize=20,fontweight='bold',pad=30)
ax.legend(loc='upper left',fontsize=13)
# Out:
# c:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## variance by continent

# %%
xrate_index_df['Continent']=xrate_index_df.apply(country_to_continent,axis=1)
xrate_index_df.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14460\182027112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xrate_index_df['Continent']=xrate_index_df.apply(country_to_continent,axis=1)
#        Country  dollar_ex  dollar_ppp  dollar_price      Continent
# 0  Switzerland    0.96845    1.262136      6.711756         Europe
# 1       Norway    9.89765   12.038835      6.264113         Europe
# 2      Uruguay   41.91000   49.514563      6.084467  South America
# 3       Sweden   10.19785   11.067961      5.589413         Europe
# 4       Canada    1.28915    1.314563      5.251522  North America

# %%
xrate_index_df.sort_values(by='dollar_price',ascending=False)
# Out:
#                  Country     dollar_ex    dollar_ppp  dollar_price  \
# 0            Switzerland      0.968450      1.262136      6.711756
# 1                 Norway      9.897650     12.038835      6.264113
# 2                Uruguay     41.910000     49.514563      6.084467
# 3                 Sweden     10.197850     11.067961      5.589413
# 4                 Canada      1.289150      1.314563      5.251522
# 5          United States      1.000000      1.000000      5.150000
# 6                Lebanon  25600.000000  25242.718447      5.078125
# 7                 Israel      3.437450      3.300971      4.945526
# 8   United Arab Emirates      3.673050      3.495146      4.900559
# 9              Euro area      0.975850      0.902913      4.765077
# 10             Australia      1.448436      1.300971      4.625680
# 11             Argentina    129.115000    114.563107      4.569570
# 12          Saudi Arabia      3.755000      3.300971      4.527297
# 13               Britain      0.831080      0.716505      4.440006
# 14           New Zealand      1.603721      1.378641      4.427205
# 15                Brazil      5.391750      4.446602      4.247230
# 16               Bahrain      0.377000      0.310680      4.244032
# 17             Singapore      1.391400      1.145631      4.240333
# 18                Kuwait      0.307400      0.252427      4.229018
# 19        Czech Republic     23.920000     18.446602      3.971572
# 20            Costa Rica    678.105000    514.563107      3.907949
# 21             Nicaragua     35.890000     26.990291      3.872945
# 22             Sri Lanka    360.000000    260.194175      3.722222
# 23                  Oman      0.385000      0.275728      3.688312
# 24               Croatia      7.328450      5.242718      3.684272
# 25                 Chile    928.435000    660.194175      3.662077
# 26              Honduras     24.615000     17.281553      3.615681
# 27                Poland      4.648450      3.238835      3.588293
# 28                  Peru      3.892850      2.699029      3.570649
# 29                 Qatar      3.641750      2.524272      3.569712
# 30                 China      6.747350      4.660194      3.556952
# 31           South Korea   1313.450000    893.203883      3.502227
# 32              Thailand     36.612500     24.854369      3.496074
# 33              Colombia   4295.100000   2902.912621      3.480711
# 34                Mexico     20.412500     13.592233      3.429271
# 35             Guatemala      7.727900      5.048544      3.364433
# 36                Jordan      0.710150      0.446602      3.238752
# 37              Pakistan    221.750000    135.922330      3.156708
# 38               Moldova     19.298000     11.650485      3.109130
# 39               Vietnam  23417.000000  13398.058252      2.946577
# 40                 Japan    137.865000     75.728155      2.828854
# 41            Azerbaijan      1.698250      0.912621      2.767555
# 42           Philippines     56.265000     30.097087      2.754821
# 43                Turkey     17.565000      9.126214      2.675776
# 44             Hong Kong      7.849950      4.077670      2.675176
# 45               Hungary    389.046150    200.000000      2.647501
# 46                Taiwan     29.907500     14.563107      2.507732
# 47              Malaysia      4.450000      2.116505      2.449438
# 48                 Egypt     18.945000      8.932039      2.428081
# 49                 India     79.951300     37.087379      2.388954
# 50          South Africa     17.036250      7.747573      2.342065
# 51             Indonesia  14977.500000   6796.116505      2.336839
# 52               Romania      4.821750      2.135922      2.281329
# 53             Venezuela      5.673200      1.941748      1.762674
#
#         Continent
# 0          Europe
# 1          Europe
# 2   South America
# 3          Europe
# 4   North America
# 5   North America
# 6            Asia
# 7            Asia
# 8            Asia
# 9          Europe
# 10        Oceania
# 11  South America
# 12           Asia
# 13         Europe
# 14        Oceania
# 15  South America
# 16           Asia
# 17           Asia
# 18           Asia
# 19         Europe
# 20  North America
# 21  North America
# 22           Asia
# 23           Asia
# 24         Europe
# 25  South America
# 26  North America
# 27         Europe
# 28  South America
# 29           Asia
# 30           Asia
# 31           Asia
# 32           Asia
# 33  South America
# 34  North America
# 35  North America
# 36           Asia
# 37           Asia
# 38         Europe
# 39           Asia
# 40           Asia
# 41           Asia
# 42           Asia
# 43           Asia
# 44           Asia
# 45         Europe
# 46           Asia
# 47           Asia
# 48         Africa
# 49           Asia
# 50         Africa
# 51           Asia
# 52         Europe
# 53  South America

# %%
xrate_index_df.groupby('Continent')['dollar_ppp'].std()
# Out:
# Continent
# Africa              0.837544
# Asia             5684.890793
# Europe             58.585408
# North America     190.609936
# Oceania             0.054921
# South America    1071.145688
# Name: dollar_ppp, dtype: float64

# %% [markdown]
# ## Hue by continent

# %%
_,ax=plt.subplots(1,1,figsize=(13,8))
sns.scatterplot(np.log(xrate_index_df['dollar_ppp']),np.log(xrate_index_df['dollar_ex']),ax=ax,hue='Continent',data=xrate_index_df,s=80,alpha=.7)
ax.set_xlabel('dollar purchasing power parity (log scale)',fontsize=13)
ax.set_ylabel('USD / local currency (log scale)',fontsize=13)
ax.set_title('The Big Mac Index and Currency Exchange Rate',fontsize=20,fontweight='bold',pad=30)
# Out:
# c:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'The Big Mac Index and Currency Exchange Rate')

# %%
sns.boxplot(xrate_index_df['Continent'],xrate_index_df['dollar_price'])
# Out:
# c:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Continent', ylabel='dollar_price'>

# %%
xrate_index_df.groupby('Continent')['dollar_ppp'].count()
# Out:
# Continent
# Africa            2
# Asia             25
# Europe           11
# North America     7
# Oceania           2
# South America     7
# Name: dollar_ppp, dtype: int64

# %% [markdown]
# # distribution by continent

# %%
plt.figure(figsize=(13,8))
sns.boxplot(xrate_index_df['Continent'],np.log(xrate_index_df['dollar_ppp']))
# Out:
# c:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Continent', ylabel='dollar_ppp'>
